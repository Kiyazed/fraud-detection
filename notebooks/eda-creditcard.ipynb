# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
cc = pd.read_csv(
    "../data/raw/creditcard.csv"
)

# %%
cc.shape
cc.info()
cc.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           50000 non-null  int64
#  1   Amount         50000 non-null  float64
#  2   merchant_risk  50000 non-null  float64
#  3   device_risk    50000 non-null  float64
#  4   international  50000 non-null  int64
#  5   card_age_days  50000 non-null  int64
#  6   num_items      50000 non-null  int64
#  7   online_order   50000 non-null  int64
#  8   Class          50000 non-null  int64
# dtypes: float64(3), int64(6)
# memory usage: 3.4 MB
#                 Time        Amount  merchant_risk   device_risk  \
# count   50000.000000  50000.000000   50000.000000  50000.000000
# mean    86302.457700     54.675480       0.289894      0.312821
# std     49928.278895     76.756677       0.191801      0.229653
# min         0.000000      1.000000       0.000000      0.000000
# 25%     42972.250000     16.980000       0.143000      0.127000
# 50%     86496.000000     33.230000       0.273000      0.293000
# 75%    129447.750000     64.885000       0.416000      0.466000
# max    172796.000000   4943.860000       1.000000      1.000000
#
#        international  card_age_days     num_items  online_order         Class
# count   50000.000000   50000.000000  50000.000000  50000.000000  50000.000000
# mean        0.140940     922.760320      4.005220      0.481500      0.004460
# std         0.347963     517.678387      1.999028      0.499663      0.066635
# min         0.000000      30.000000      1.000000      0.000000      0.000000
# 25%         0.000000     472.000000      2.000000      0.000000      0.000000
# 50%         0.000000     924.000000      4.000000      0.000000      0.000000
# 75%         0.000000    1369.000000      6.000000      1.000000      0.000000
# max         1.000000    1824.000000      7.000000      1.000000      1.000000

# %%
cc["Class"].value_counts()
# Out:
# Class
# 0    49777
# 1      223
# Name: count, dtype: int64

# %%
sns.countplot(
    x="Class",
    data=cc
)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
sns.histplot(
    cc["Amount"]
)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
corr = cc.corr()

plt.figure(figsize=(12,8))

sns.heatmap(
    corr,
    cmap="coolwarm"
)

plt.show()
